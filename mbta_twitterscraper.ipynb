# %%
# docs live in old package: https://pypi.org/project/twitterscraper/0.2.7/
# %pip install twitterscraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from twitterscraper import query_tweets

QUERY = 'Red line delayed (from:mbta)'
# for tweet in query_tweets("mbta", 10)[:10]:
#     print(tweet.user.encode('utf-8'))

tweets = query_tweets(QUERY, 100)
for tweet in tweets[:100]:
    print(tweet.text)
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}
# ...

# %%
tweets[0:5]

# %% [markdown]
# !! doesn't return comments

# %%
# https://pypi.org/project/GetOldTweets3/ 
# doesn't return comment text only num replies
# import GetOldTweets3 as got
